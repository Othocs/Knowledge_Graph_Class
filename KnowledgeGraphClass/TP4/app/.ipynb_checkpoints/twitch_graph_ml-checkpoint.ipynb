# %% [markdown]
# # TP4 - Twitch Stream Language Prediction using Graph ML
#
# This notebook demonstrates how to use Graph Data Science (GDS) with Neo4j to predict stream languages based on shared audience patterns.
#
# ## Objectives
# 1. Load Twitch stream data into Neo4j
# 2. Create graph projection for GDS algorithms
# 3. Generate node embeddings using node2vec
# 4. Train RandomForest classifier for language prediction
# 5. Visualize and analyze results

# %% [markdown]
# ## Setup and Configuration

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from neo4j import GraphDatabase
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.metrics.pairwise import euclidean_distances, cosine_similarity
from scipy.spatial.distance import pdist, squareform
import warnings
warnings.filterwarnings('ignore')

# Set style for visualizations
sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (12, 6)

# Neo4j connection parameters
NEO4J_URI = os.getenv("NEO4J_URI", "bolt://neo4j:7687")
NEO4J_USER = os.getenv("NEO4J_USER", "neo4j")
NEO4J_PASSWORD = os.getenv("NEO4J_PASSWORD", "password123")

print("✓ Imports successful")
# Out:
# ✓ Imports successful

# %%
# Connect to Neo4j
driver = GraphDatabase.driver(NEO4J_URI, auth=(NEO4J_USER, NEO4J_PASSWORD))

def run_query(query, parameters=None):
    """Execute a Cypher query and return results as list of records"""
    with driver.session() as session:
        result = session.run(query, parameters or {})
        return [record.data() for record in result]

# Test connection
result = run_query("RETURN 'Connected to Neo4j!' AS message")
print(result[0]['message'])
# Out:
# Connected to Neo4j!

# %% [markdown]
# ## 1. Data Loading and Exploration

# %%
# Check if data is already loaded
stream_count = run_query("MATCH (s:Stream) RETURN count(s) AS count")[0]['count']

if stream_count == 0:
    print("No data found. Running ETL script...")
    # !python /workspace/load_data.py
else:
    print(f"✓ Data already loaded: {stream_count} streams")
# Out:
# ✓ Data already loaded: 3721 streams

# %%
# Database statistics
stats = run_query("""
    MATCH (s:Stream)
    WITH count(s) AS streamCount
    MATCH ()-[r:SHARED_AUDIENCE]->()
    RETURN streamCount, count(r) AS relationshipCount
""")

print(f"Streams: {stats[0]['streamCount']}")
print(f"Relationships: {stats[0]['relationshipCount']}")
# Out:
# Streams: 3721
# Relationships: 262854

# %%
# Language distribution
lang_dist = run_query("""
    MATCH (s:Stream)
    RETURN s.language AS language, count(s) AS count
    ORDER BY count DESC
""")

lang_df = pd.DataFrame(lang_dist)
print("\nLanguage Distribution:")
print(lang_df)

# Visualize language distribution
plt.figure(figsize=(10, 6))
sns.barplot(data=lang_df, x='language', y='count', palette='viridis')
plt.title('Stream Language Distribution', fontsize=14, fontweight='bold')
plt.xlabel('Language')
plt.ylabel('Number of Streams')
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('/workspace/media/language_distribution.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# Language Distribution:
#   language  count
# 0       en   1817
# 1       es    306
# 2       de    279
# 3       ko    257
# 4       ru    254
# 5       fr    249
# 6    pt-br    192
# 7       it    132
# 8       tr    129
# 9    zh-tw    106

# %% [markdown]
# ## 2. Degree Distribution Analysis

# %%
# Calculate degree for each stream
degree_data = run_query("""
    MATCH (s:Stream)
    WITH s, count{(s)-[:SHARED_AUDIENCE]-()} AS degree
    RETURN s.id AS streamId, s.language AS language, degree
    ORDER BY degree DESC
""")

degree_df = pd.DataFrame(degree_data)
print(f"Average degree: {degree_df['degree'].mean():.2f}")
print(f"Max degree: {degree_df['degree'].max()}")
print(f"Min degree: {degree_df['degree'].min()}")
# Out:
# Average degree: 141.28
# Max degree: 3974
# Min degree: 2

# %%
# Visualize degree distribution
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Histogram
axes[0].hist(degree_df['degree'], bins=30, color='steelblue', edgecolor='black', alpha=0.7)
axes[0].set_xlabel('Degree')
axes[0].set_ylabel('Frequency')
axes[0].set_title('Degree Distribution', fontweight='bold')
axes[0].axvline(degree_df['degree'].mean(), color='red', linestyle='--', label=f"Mean: {degree_df['degree'].mean():.2f}")
axes[0].legend()

# Box plot by language
sns.boxplot(data=degree_df, x='language', y='degree', palette='Set2', ax=axes[1])
axes[1].set_xlabel('Language')
axes[1].set_ylabel('Degree')
axes[1].set_title('Degree Distribution by Language', fontweight='bold')
axes[1].tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.savefig('/workspace/media/degree_distribution.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## 3. Graph Projection for GDS

# %%
# Drop existing projection if it exists
try:
    run_query("CALL gds.graph.drop('twitchNetwork', false)")
    print("✓ Dropped existing graph projection")
except:
    print("No existing projection to drop")
# Out:
# Received notification from DBMS server: <GqlStatusObject gql_status='01N42', status_description="The query used a deprecated field from a procedure. ('schema' returned by 'gds.graph.drop' is deprecated.)", position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/', '_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'column': 1, 'offset': 0, 'line': 1}}> for query: "CALL gds.graph.drop('twitchNetwork', false)"
# ✓ Dropped existing graph projection

# %%
# Create undirected graph projection
projection_result = run_query("""
    CALL gds.graph.project(
        'twitchNetwork',
        'Stream',
        {
            SHARED_AUDIENCE: {
                orientation: 'UNDIRECTED'
            }
        }
    )
    YIELD nodeCount, relationshipCount
    RETURN nodeCount, relationshipCount
""")

print(f"✓ Graph projection created")
print(f"  Nodes: {projection_result[0]['nodeCount']}")
print(f"  Relationships: {projection_result[0]['relationshipCount']}")
print(f"  Note: Language labels will be fetched separately after embeddings are generated")
# Out:
# ✓ Graph projection created
#   Nodes: 3721
#   Relationships: 525708
#   Note: Language labels will be fetched separately after embeddings are generated

# %% [markdown]
# ## 4. Node2Vec Embeddings

# %%
# Generate node2vec embeddings
print("Generating node2vec embeddings (this may take a moment)...")

embedding_result = run_query("""
    CALL gds.node2vec.write('twitchNetwork', {
        embeddingDimension: 64,
        walkLength: 80,
        walksPerNode: 10,
        iterations: 1,
        writeProperty: 'embedding'
    })
    YIELD nodePropertiesWritten
    RETURN nodePropertiesWritten
""")

print(f"✓ Generated embeddings for {embedding_result[0]['nodePropertiesWritten']} nodes")
# Out:
# Generating node2vec embeddings (this may take a moment)...
# ✓ Generated embeddings for 3721 nodes

# %%
# Fetch embeddings and labels
embedding_data = run_query("""
    MATCH (s:Stream)
    WHERE s.embedding IS NOT NULL
    RETURN s.id AS streamId, s.language AS language, s.embedding AS embedding
""")

# Convert to DataFrame
embedding_df = pd.DataFrame(embedding_data)
print(f"✓ Retrieved {len(embedding_df)} embeddings")
print(f"  Embedding dimension: {len(embedding_df['embedding'].iloc[0])}")
# Out:
# ✓ Retrieved 3721 embeddings
#   Embedding dimension: 64

# %% [markdown]
# ## 5. Distance Analysis: Euclidean vs Cosine

# %%
# Prepare embeddings matrix
X = np.array(embedding_df['embedding'].tolist())
print(f"Embeddings matrix shape: {X.shape}")

# Calculate Euclidean distances
euclidean_dist = pdist(X, metric='euclidean')
euclidean_dist_matrix = squareform(euclidean_dist)

# Calculate Cosine distances (1 - cosine similarity)
cosine_sim_matrix = cosine_similarity(X)
cosine_dist_matrix = 1 - cosine_sim_matrix

# Flatten upper triangle (to avoid duplicates)
triu_indices = np.triu_indices_from(euclidean_dist_matrix, k=1)
euclidean_flat = euclidean_dist_matrix[triu_indices]
cosine_flat = cosine_dist_matrix[triu_indices]

print(f"\nEuclidean distance stats:")
print(f"  Mean: {euclidean_flat.mean():.4f}")
print(f"  Std: {euclidean_flat.std():.4f}")
print(f"  Min: {euclidean_flat.min():.4f}")
print(f"  Max: {euclidean_flat.max():.4f}")

print(f"\nCosine distance stats:")
print(f"  Mean: {cosine_flat.mean():.4f}")
print(f"  Std: {cosine_flat.std():.4f}")
print(f"  Min: {cosine_flat.min():.4f}")
print(f"  Max: {cosine_flat.max():.4f}")
# Out:
# Embeddings matrix shape: (3721, 64)
#
# Euclidean distance stats:
#   Mean: 2.8806
#   Std: 0.6369
#   Min: 0.0675
#   Max: 6.3420
#
# Cosine distance stats:
#   Mean: 0.5871
#   Std: 0.1546
#   Min: 0.0001
#   Max: 1.1010

# %%
# Visualize distance distributions
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Euclidean distance distribution
axes[0].hist(euclidean_flat, bins=50, color='coral', edgecolor='black', alpha=0.7)
axes[0].axvline(euclidean_flat.mean(), color='red', linestyle='--', label=f'Mean: {euclidean_flat.mean():.4f}')
axes[0].set_xlabel('Euclidean Distance')
axes[0].set_ylabel('Frequency')
axes[0].set_title('Euclidean Distance Distribution', fontweight='bold')
axes[0].legend()

# Cosine distance distribution
axes[1].hist(cosine_flat, bins=50, color='skyblue', edgecolor='black', alpha=0.7)
axes[1].axvline(cosine_flat.mean(), color='red', linestyle='--', label=f'Mean: {cosine_flat.mean():.4f}')
axes[1].set_xlabel('Cosine Distance')
axes[1].set_ylabel('Frequency')
axes[1].set_title('Cosine Distance Distribution', fontweight='bold')
axes[1].legend()

plt.tight_layout()
plt.savefig('/workspace/media/distance_distributions.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## 6. Language-Specific Distance Analysis

# %%
# Analyze distances within same language vs different languages
languages = embedding_df['language'].values
n = len(languages)

same_lang_euclidean = []
diff_lang_euclidean = []
same_lang_cosine = []
diff_lang_cosine = []

for i in range(n):
    for j in range(i+1, n):
        if languages[i] == languages[j]:
            same_lang_euclidean.append(euclidean_dist_matrix[i, j])
            same_lang_cosine.append(cosine_dist_matrix[i, j])
        else:
            diff_lang_euclidean.append(euclidean_dist_matrix[i, j])
            diff_lang_cosine.append(cosine_dist_matrix[i, j])

print("Same Language:")
print(f"  Euclidean - Mean: {np.mean(same_lang_euclidean):.4f}, Std: {np.std(same_lang_euclidean):.4f}")
print(f"  Cosine - Mean: {np.mean(same_lang_cosine):.4f}, Std: {np.std(same_lang_cosine):.4f}")

print("\nDifferent Languages:")
print(f"  Euclidean - Mean: {np.mean(diff_lang_euclidean):.4f}, Std: {np.std(diff_lang_euclidean):.4f}")
print(f"  Cosine - Mean: {np.mean(diff_lang_cosine):.4f}, Std: {np.std(diff_lang_cosine):.4f}")
# Out:
# Same Language:
#   Euclidean - Mean: 2.4121, Std: 0.7032
#   Cosine - Mean: 0.4969, Std: 0.1937
#
# Different Languages:
#   Euclidean - Mean: 3.0542, Std: 0.5110
#   Cosine - Mean: 0.6205, Std: 0.1214

# %%
# Visualize same vs different language distances
fig, axes = plt.subplots(2, 2, figsize=(14, 10))

# Euclidean - same language
axes[0, 0].hist(same_lang_euclidean, bins=30, color='green', alpha=0.6, label='Same Language')
axes[0, 0].hist(diff_lang_euclidean, bins=30, color='red', alpha=0.6, label='Different Languages')
axes[0, 0].set_xlabel('Euclidean Distance')
axes[0, 0].set_ylabel('Frequency')
axes[0, 0].set_title('Euclidean Distance: Same vs Different Languages', fontweight='bold')
axes[0, 0].legend()

# Cosine - same language
axes[0, 1].hist(same_lang_cosine, bins=30, color='green', alpha=0.6, label='Same Language')
axes[0, 1].hist(diff_lang_cosine, bins=30, color='red', alpha=0.6, label='Different Languages')
axes[0, 1].set_xlabel('Cosine Distance')
axes[0, 1].set_ylabel('Frequency')
axes[0, 1].set_title('Cosine Distance: Same vs Different Languages', fontweight='bold')
axes[0, 1].legend()

# Box plots for comparison
data_euclidean = pd.DataFrame({
    'Distance': same_lang_euclidean + diff_lang_euclidean,
    'Type': ['Same']*len(same_lang_euclidean) + ['Different']*len(diff_lang_euclidean)
})

data_cosine = pd.DataFrame({
    'Distance': same_lang_cosine + diff_lang_cosine,
    'Type': ['Same']*len(same_lang_cosine) + ['Different']*len(diff_lang_cosine)
})

sns.boxplot(data=data_euclidean, x='Type', y='Distance', palette='Set2', ax=axes[1, 0])
axes[1, 0].set_title('Euclidean Distance Box Plot', fontweight='bold')

sns.boxplot(data=data_cosine, x='Type', y='Distance', palette='Set2', ax=axes[1, 1])
axes[1, 1].set_title('Cosine Distance Box Plot', fontweight='bold')

plt.tight_layout()
plt.savefig('/workspace/media/language_distance_comparison.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## 7. RandomForest Classifier Training

# %%
# Prepare training data
X = np.array(embedding_df['embedding'].tolist())
y = embedding_df['language'].values

# Split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42, stratify=y
)

print(f"Training set: {len(X_train)} samples")
print(f"Test set: {len(X_test)} samples")
print(f"\nClass distribution in training:")
print(pd.Series(y_train).value_counts())
# Out:
# Training set: 2604 samples
# Test set: 1117 samples
#
# Class distribution in training:
# en       1272
# es        214
# de        195
# ko        180
# ru        178
# fr        174
# pt-br     134
# it         93
# tr         90
# zh-tw      74
# Name: count, dtype: int64

# %%
# Train RandomForest classifier
print("Training RandomForest classifier...")

clf = RandomForestClassifier(
    n_estimators=100,
    max_depth=10,
    min_samples_split=5,
    random_state=42,
    n_jobs=-1
)

clf.fit(X_train, y_train)
print("✓ Model trained")
# Out:
# Training RandomForest classifier...
# ✓ Model trained

# %%
# Make predictions
y_pred = clf.predict(X_test)
y_pred_proba = clf.predict_proba(X_test)

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"\nTest Accuracy: {accuracy:.4f}")

# Classification report
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Test Accuracy: 0.8988
#
# Classification Report:
#               precision    recall  f1-score   support
#
#           de       0.90      0.85      0.87        84
#           en       0.88      0.92      0.90       545
#           es       0.88      0.91      0.90        92
#           fr       0.96      0.92      0.94        75
#           it       0.94      0.87      0.91        39
#           ko       0.99      0.91      0.95        77
#        pt-br       0.87      0.81      0.84        58
#           ru       0.89      0.84      0.86        76
#           tr       0.90      0.90      0.90        39
#        zh-tw       0.97      0.91      0.94        32
#
#     accuracy                           0.90      1117
#    macro avg       0.92      0.88      0.90      1117
# weighted avg       0.90      0.90      0.90      1117

# %%
# Confusion matrix
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
            xticklabels=clf.classes_, yticklabels=clf.classes_)
plt.title('Confusion Matrix', fontsize=14, fontweight='bold')
plt.xlabel('Predicted Language')
plt.ylabel('True Language')
plt.tight_layout()
plt.savefig('/workspace/media/confusion_matrix.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# Feature importance (top 20 embedding dimensions)
feature_importance = clf.feature_importances_
top_features_idx = np.argsort(feature_importance)[-20:][::-1]

plt.figure(figsize=(10, 6))
plt.barh(range(len(top_features_idx)), feature_importance[top_features_idx], color='teal')
plt.yticks(range(len(top_features_idx)), [f'Dim {i}' for i in top_features_idx])
plt.xlabel('Feature Importance')
plt.title('Top 20 Most Important Embedding Dimensions', fontsize=14, fontweight='bold')
plt.gca().invert_yaxis()
plt.tight_layout()
plt.savefig('/workspace/media/feature_importance.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## 8. Questions to Answer
#
# ### Question 1: How does the classifier perform compared to a baseline?
#
# Let's compare with a random baseline:

# %%
# Calculate baseline accuracy (random guessing based on class distribution)
class_distribution = pd.Series(y_train).value_counts(normalize=True)
baseline_accuracy = (class_distribution ** 2).sum()

print(f"Baseline Accuracy (random guessing): {baseline_accuracy:.4f}")
print(f"RandomForest Accuracy: {accuracy:.4f}")
print(f"Improvement over baseline: {(accuracy - baseline_accuracy) / baseline_accuracy * 100:.2f}%")

# Visualize comparison
fig, ax = plt.subplots(figsize=(8, 6))
models = ['Baseline\n(Random)', 'RandomForest']
accuracies = [baseline_accuracy, accuracy]
colors = ['lightcoral', 'lightgreen']

bars = ax.bar(models, accuracies, color=colors, edgecolor='black', alpha=0.7)
ax.set_ylabel('Accuracy')
ax.set_title('Model Performance Comparison', fontsize=14, fontweight='bold')
ax.set_ylim([0, 1])

# Add value labels on bars
for bar, acc in zip(bars, accuracies):
    height = bar.get_height()
    ax.text(bar.get_x() + bar.get_width()/2., height + 0.02,
            f'{acc:.4f}', ha='center', va='bottom', fontweight='bold')

plt.tight_layout()
plt.savefig('/workspace/media/model_comparison.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# Baseline Accuracy (random guessing): 0.2708
# RandomForest Accuracy: 0.8988
# Improvement over baseline: 231.90%

# %% [markdown]
# ### Question 2: Which languages are easiest/hardest to predict?

# %%
# Calculate per-class metrics
from sklearn.metrics import precision_recall_fscore_support

precision, recall, f1, support = precision_recall_fscore_support(y_test, y_pred)

metrics_df = pd.DataFrame({
    'Language': clf.classes_,
    'Precision': precision,
    'Recall': recall,
    'F1-Score': f1,
    'Support': support
}).sort_values('F1-Score', ascending=False)

print("Per-Language Performance:")
print(metrics_df.to_string(index=False))

# Visualize
fig, axes = plt.subplots(1, 3, figsize=(15, 5))

for idx, metric in enumerate(['Precision', 'Recall', 'F1-Score']):
    sns.barplot(data=metrics_df, x='Language', y=metric, palette='viridis', ax=axes[idx])
    axes[idx].set_title(f'{metric} by Language', fontweight='bold')
    axes[idx].set_ylim([0, 1])
    axes[idx].tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.savefig('/workspace/media/per_language_performance.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# Per-Language Performance:
# Language  Precision   Recall  F1-Score  Support
#       ko   0.985915 0.909091  0.945946       77
#       fr   0.958333 0.920000  0.938776       75
#    zh-tw   0.966667 0.906250  0.935484       32
#       it   0.944444 0.871795  0.906667       39
#       en   0.880492 0.919266  0.899461      545
#       es   0.884211 0.913043  0.898396       92
#       tr   0.897436 0.897436  0.897436       39
#       de   0.898734 0.845238  0.871166       84
#       ru   0.888889 0.842105  0.864865       76
#    pt-br   0.870370 0.810345  0.839286       58

# %% [markdown]
# ### Question 3: How does embedding quality affect prediction accuracy?

# %%
# Analyze prediction confidence
max_probs = y_pred_proba.max(axis=1)
correct_mask = (y_pred == y_test)

correct_probs = max_probs[correct_mask]
incorrect_probs = max_probs[~correct_mask]

print(f"Average confidence for correct predictions: {correct_probs.mean():.4f}")
print(f"Average confidence for incorrect predictions: {incorrect_probs.mean():.4f}")

# Visualize confidence distributions
plt.figure(figsize=(10, 6))
plt.hist(correct_probs, bins=30, alpha=0.6, label='Correct Predictions', color='green')
plt.hist(incorrect_probs, bins=30, alpha=0.6, label='Incorrect Predictions', color='red')
plt.xlabel('Prediction Confidence (Max Probability)')
plt.ylabel('Frequency')
plt.title('Prediction Confidence Distribution', fontsize=14, fontweight='bold')
plt.legend()
plt.tight_layout()
plt.savefig('/workspace/media/prediction_confidence.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# Average confidence for correct predictions: 0.8554
# Average confidence for incorrect predictions: 0.6819

# %%
# Analyze relationship between degree and prediction accuracy
test_indices = X_test
test_stream_ids = embedding_df.iloc[range(len(X))].iloc[
    [i for i in range(len(X)) if any(np.array_equal(X[i], x) for x in X_test)]
]['streamId'].values[:len(y_test)]

# Get degrees for test streams
test_degrees = []
for stream_id in test_stream_ids[:len(y_test)]:
    degree_query = run_query("""
        MATCH (s:Stream {id: $streamId})
        RETURN count{(s)-[:SHARED_AUDIENCE]-()} AS degree
    """, {"streamId": int(stream_id)})
    test_degrees.append(degree_query[0]['degree'] if degree_query else 0)

# Create analysis DataFrame
analysis_df = pd.DataFrame({
    'degree': test_degrees[:len(y_test)],
    'correct': correct_mask,
    'confidence': max_probs
})

# Bin by degree
analysis_df['degree_bin'] = pd.cut(analysis_df['degree'], bins=5)
accuracy_by_degree = analysis_df.groupby('degree_bin')['correct'].mean()

print("\nAccuracy by Degree Range:")
print(accuracy_by_degree)

plt.figure(figsize=(10, 6))
accuracy_by_degree.plot(kind='bar', color='steelblue', edgecolor='black')
plt.xlabel('Degree Range')
plt.ylabel('Accuracy')
plt.title('Prediction Accuracy vs Node Degree', fontsize=14, fontweight='bold')
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('/workspace/media/accuracy_vs_degree.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# [#9F62]  _: <CONNECTION> error: Failed to read from defunct connection IPv4Address(('neo4j', 7687)) (ResolvedIPv4Address(('172.18.0.2', 7687))): OSError('No data')
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File /usr/local/lib/python3.11/site-packages/neo4j/_sync/io/_common.py:53, in Inbox._buffer_one_chunk(self)
#      51 while chunk_size == 0:
#      52     # Determine the chunk size and skip noop
# ---> 53     receive_into_buffer(self._socket, self._buffer, 2)
#      54     chunk_size = self._buffer.pop_u16()
#
# File /usr/local/lib/python3.11/site-packages/neo4j/_sync/io/_common.py:343, in receive_into_buffer(sock, buffer, n_bytes)
#     342 if n == 0:
# --> 343     raise OSError("No data")
#     344 buffer.used += n
#
# OSError: No data
#
# The above exception was the direct cause of the following exception:
#
# ServiceUnavailable                        Traceback (most recent call last)
# Cell In[24], line 10
#       8 test_degrees = []
#       9 for stream_id in test_stream_ids[:len(y_test)]:
# ---> 10     degree_query = run_query("""
#      11         MATCH (s:Stream {id: $streamId})
#      12         RETURN count{(s)-[:SHARED_AUDIENCE]-()} AS degree
#      13     """, {"streamId": int(stream_id)})
#      14     test_degrees.append(degree_query[0]['degree'] if degree_query else 0)
#      16 # Create analysis DataFrame
#
# Cell In[2], line 7, in run_query(query, parameters)
#       5 """Execute a Cypher query and return results as list of records"""
#       6 with driver.session() as session:
# ----> 7     result = session.run(query, parameters or {})
#       8     return [record.data() for record in result]
#
# File /usr/local/lib/python3.11/site-packages/neo4j/_sync/work/session.py:320, in Session.run(self, query, parameters, **kwargs)
#     318 bookmarks = self._get_bookmarks()
#     319 parameters = dict(parameters or {}, **kwargs)
# --> 320 self._auto_result._run(
#     321     query,
#     322     parameters,
#     323     self._config.database,
#     324     self._config.impersonated_user,
#     325     self._config.default_access_mode,
#     326     bookmarks,
#     327     self._config.notifications_min_severity,
#     328     self._config.notifications_disabled_classifications,
#     329 )
#     331 return self._auto_result
#
# File /usr/local/lib/python3.11/site-packages/neo4j/_sync/work/result.py:237, in Result._run(self, query, parameters, db, imp_user, access_mode, bookmarks, notifications_min_severity, notifications_disabled_classifications)
#     235 self._pull()
#     236 self._connection.send_all()
# --> 237 self._attach()
#
# File /usr/local/lib/python3.11/site-packages/neo4j/_sync/work/result.py:439, in Result._attach(self)
#     437 if self._exhausted is False:
#     438     while self._attached is False:
# --> 439         self._connection.fetch_message()
#
# File /usr/local/lib/python3.11/site-packages/neo4j/_sync/io/_common.py:192, in ConnectionErrorHandler.__getattr__.<locals>.outer.<locals>.inner(*args, **kwargs)
#     190 def inner(*args, **kwargs):
#     191     try:
# --> 192         func(*args, **kwargs)
#     193     except (Neo4jError, ServiceUnavailable, SessionExpired) as exc:
#     194         assert not asyncio.iscoroutinefunction(self.__on_error)
#
# File /usr/local/lib/python3.11/site-packages/neo4j/_sync/io/_bolt.py:863, in Bolt.fetch_message(self)
#     860     return 0, 0
#     862 # Receive exactly one message
# --> 863 tag, fields = self.inbox.pop(
#     864     hydration_hooks=self.responses[0].hydration_hooks
#     865 )
#     866 res = self._process_message(tag, fields)
#     867 self.idle_since = monotonic()
#
# File /usr/local/lib/python3.11/site-packages/neo4j/_sync/io/_common.py:76, in Inbox.pop(self, hydration_hooks)
#      75 def pop(self, hydration_hooks):
# ---> 76     self._buffer_one_chunk()
#      77     try:
#      78         size, tag = self._unpacker.unpack_structure_header()
#
# File /usr/local/lib/python3.11/site-packages/neo4j/_sync/io/_common.py:72, in Inbox._buffer_one_chunk(self)
#      66 except (
#      67     OSError,
#      68     SocketDeadlineExceededError,
#      69     asyncio.CancelledError,
#      70 ) as error:
#      71     self._broken = True
# ---> 72     Util.callback(self.on_error, error)
#      73     raise
#
# File /usr/local/lib/python3.11/site-packages/neo4j/_async_compat/util.py:105, in Util.callback(cb, *args, **kwargs)
#     102 @staticmethod
#     103 def callback(cb, *args, **kwargs):
#     104     if callable(cb):
# --> 105         return cb(*args, **kwargs)
#     106     return None
#
# File /usr/local/lib/python3.11/site-packages/neo4j/_sync/io/_bolt.py:891, in Bolt._set_defunct_read(self, error, silent)
#     886 def _set_defunct_read(self, error=None, silent=False):
#     887     message = (
#     888         "Failed to read from defunct connection "
#     889         f"{self.unresolved_address!r} ({self.server_info.address!r})"
#     890     )
# --> 891     self._set_defunct(message, error=error, silent=silent)
#
# File /usr/local/lib/python3.11/site-packages/neo4j/_sync/io/_bolt.py:970, in Bolt._set_defunct(self, message, error, silent)
#     968 if direct_driver:
#     969     if error:
# --> 970         raise ServiceUnavailable(message) from error
#     971     else:
#     972         raise ServiceUnavailable(message)
#
# ServiceUnavailable: Failed to read from defunct connection IPv4Address(('neo4j', 7687)) (ResolvedIPv4Address(('172.18.0.2', 7687)))

# %% [markdown]
# ## 9. Summary and Conclusions

# %%
print("="*60)
print("TP4 - SUMMARY")
print("="*60)
print(f"\nDataset:")
print(f"  - Total streams: {len(embedding_df)}")
print(f"  - Languages: {', '.join(sorted(embedding_df['language'].unique()))}")
print(f"  - Average degree: {degree_df['degree'].mean():.2f}")
print(f"\nEmbeddings:")
print(f"  - Dimension: {X.shape[1]}")
print(f"  - Generated using: node2vec")
print(f"\nClassifier Performance:")
print(f"  - Model: RandomForest (100 trees)")
print(f"  - Test Accuracy: {accuracy:.4f}")
print(f"  - Baseline Accuracy: {baseline_accuracy:.4f}")
print(f"  - Improvement: {(accuracy - baseline_accuracy) / baseline_accuracy * 100:.2f}%")
print(f"\nDistance Metrics:")
print(f"  - Euclidean (same language): {np.mean(same_lang_euclidean):.4f}")
print(f"  - Euclidean (different languages): {np.mean(diff_lang_euclidean):.4f}")
print(f"  - Cosine (same language): {np.mean(same_lang_cosine):.4f}")
print(f"  - Cosine (different languages): {np.mean(diff_lang_cosine):.4f}")
print(f"\nKey Insights:")
print(f"  1. Graph structure (shared audiences) contains language signal")
print(f"  2. Node2vec embeddings capture meaningful patterns")
print(f"  3. RandomForest successfully predicts languages from embeddings")
print(f"  4. {'Cosine' if np.mean(same_lang_cosine) < np.mean(diff_lang_cosine) else 'Euclidean'} distance shows better language separation")
print("="*60)

print("\n✓ All visualizations saved to /workspace/media/")

# %% [markdown]
# ## Cleanup

# %%
# Close Neo4j connection
driver.close()
print("✓ Neo4j connection closed")
